# %%
import numpy
import scipy
import pandas

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %matplotlib inline

# %%
sys.path.append(os.path.join(os.path.abspath('../..'), 'src'))
sys.path.append(os.path.join(os.path.abspath('../..'), 'data'))

# %%
import utils

# %%
senators = utils.load_election_data('senate', '2014')
reprs = utils.load_election_data('house', '2014')

# %%
senators.head()
# Out:
#   District Session Chamber                Name Party Incombant    Won   Votes
# 0        1    2014       S          Stan White     D        NA  False  27,957
# 1        1    2014       S           Bill Cook     R        NA   True  32,143
# 2        2    2014       S    Carroll Ipock II     D        NA  False  23,925
# 3        2    2014       S    Norman Sanderson     R        NA   True  36,562
# 4        3    2014       S  Erica Smith-Ingram     D        NA   True      NA

# %%
reprs.head()
# Out:
#   District Session Chamber              Name Party Incombant    Won   Votes
# 0        1    2014       H      Garry Meiggs     D        NA  False  10,082
# 1        1    2014       H     Bob Steinburg     R        NA   True  15,713
# 2        2    2014       H       Ray Jeffers     D        NA  False  10,259
# 3        2    2014       H  Larry Yarborough     R        NA   True  13,423
# 4        3    2014       H      Whit Whitley     D        NA  False  10,524

# %%
btfc = utils.load_filed_bill_data()

# %%
btfc.head()
# Out:
#   session house  bill                                            content  \
# 0  2015E4     H     1  GENERAL ASSEMBLY OF NORTH CAROLINA  FOURTH EXT...
# 1  2015E4     H     2  GENERAL ASSEMBLY OF NORTH CAROLINA  FOURTH EXT...
# 2  2015E4     H     3  GENERAL ASSEMBLY OF NORTH CAROLINA  FOURTH EXT...
# 3  2015E4     H     4  GENERAL ASSEMBLY OF NORTH CAROLINA  FOURTH EXT...
# 4  2015E4     H     5  GENERAL ASSEMBLY OF NORTH CAROLINA  FOURTH EXT...
#
#                                           long_title  \
# 0  A HOUSE RESOLUTION adopting the permanent rule...
# 1  A JOINT RESOLUTIOn providing for adjournment s...
# 2  AN ACT to provide further REGULATORY RELIEF TO...
# 3  AN ACT directing the department of transportat...
# 4  AN ACT to clarify the service area for communi...
#
#                                           table_info  \
# 0  {'Sponsors': 'Representative Lewis.', 'Referre...
# 1  {'Sponsors': 'Representative Lewis.', 'Referre...
# 2  {'Sponsors': 'Representatives McGrady and Dixo...
# 3  {'Sponsors': 'Representatives Cotham, Bradford...
# 4  {'Sponsors': 'Representative S. Martin.', 'Sho...
#
#                                             keywords
# 0  [ADOPTED, GENERAL ASSEMBLY, RESOLUTIONS, SIMPL...
# 1  [ADJOURNMENT, GENERAL ASSEMBLY, RESOLUTIONS, J...
# 2  [ADMINISTRATION DEPT., ADMINISTRATIVE CODE, AD...
# 3  [BRIDGES, CONTRACTS, COUNTIES, INFRASTRUCTURE,...
# 4  [COUNTIES, EDGECOMBE COUNTY, INFORMATION TECHN...

# %%
btfc.shape
# Out:
# (2098, 7)

# %% [markdown]
# ## Sponsor Names from Text

# %%
btfc.table_info[0]['Sponsors']
# Out:
# 'Representative Lewis.'

# %%
import re

# %%
sponsor_split = re.compile(r';|,| and')
known_modifiers = {'By Request', 'Primary   Sponsors', 'Primary Sponsor', 'Primary Sponsors'}

def extract_sponsors(table_info):
    
    def strip_modifiers(s):
        if s.endswith(')'):
            s = s.split('(')[0].strip()
        return(s)
    
    def parse_sponsor_string(sponsors_str, base_token):
    
        if sponsors_str[:(len(base_token) + 1)] == base_token + 's':
            nl = len(base_token) + 1
            sponsors_str = sponsors_str[nl:].strip()
            sponsors_toks = re.split(sponsor_split, sponsors_str)
            sponsors_toks = [s.strip() for s in sponsors_toks]
            sponsors_toks = [s for s in sponsors_toks if s]

        else:
            nl = len(base_token)
            sponsors_str = sponsors_str[nl:].strip()
            sponsors_toks = [sponsors_str]
            
        sponsors_toks = [strip_modifiers(s) for s in sponsors_toks]
        sponsors_toks = [s.replace(' ', '').strip() for s in sponsors_toks]
            
        return(sponsors_toks)
    
    def main(sponsors):
        sponsors = sponsors.strip('.')

        if sponsors[:14] =='Representative':
            base_token = 'Representative'
        elif sponsors[:7] =='Senator':
            base_token = 'Senator'
    
        if base_token:    
            sponsors = parse_sponsor_string(sponsors, base_token)
            
        return(sponsors)
            
    
    sponsors_raw = table_info['Sponsors']
    
    if sponsors_raw.strip()[:9] == 'Committee':
        sponsors = [sponsors_raw.strip()]
    elif sponsors_raw.find('/') > -1:
        sponsors_raw = sponsors_raw.split('/')
        sponsors = []
        for s in sponsors_raw:
            sponsors.extend(main(s))
    else:
        sponsors = main(sponsors_raw)
    
    return(sponsors)

# %%
btfc['sponsors'] = btfc.table_info.apply(lambda x: extract_sponsors(x))

# %%
def find_modifiers(sponsors_lists):
    """
    Find the set of modifiers to reps / senators names
    with regards to bill sponsorship
    """
    modifiers = []
    for ss in sponsors_lists:
        for s in ss:
            if s.endswith(')'):
                mod = s.split('(')[-1].strip(')')
                modifiers.append(mod)
                if not mod:
                    print(ss)
    modifiers = set(modifiers)
    return(modifiers)

# %% [markdown]
# ## Match Bill Sponsor Data to Sen, Rep Data

# %% [markdown]
# ## Counting, Basic Analysis

# %%
sponsor_count_data = []

def update_scd(entry):
    h = entry['house']
    b = entry['bill']
    ses = entry['session']
    for s in entry['sponsors']:
        sponsor_count_data.append({'house' : h,
                                   'bill' : b,
                                   'session' : ses,
                                   'name' : s,
                                   'lab' : s + " (" + h + ")"})
        
_ = btfc.apply(lambda x: update_scd(x), axis=1)

sponsor_count_data = pandas.DataFrame(sponsor_count_data)

# %%
sponsor_count_data.head()
# Out:
#    bill house          lab     name session
# 0     1     H    Lewis (H)    Lewis  2015E4
# 1     2     H    Lewis (H)    Lewis  2015E4
# 2     3     H  McGrady (H)  McGrady  2015E4
# 3     3     H    Dixon (H)    Dixon  2015E4
# 4     4     H   Cotham (H)   Cotham  2015E4

# %%
counts = sponsor_count_data.groupby('lab').apply(len)
counts = counts.sort_values(ascending=False)

# %%
import plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.tools import FigureFactory as FF
import plotly.graph_objs as pogo
from plotly.graph_objs import Marker, Line, Data

init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
trace0 = pogo.Bar(
    x=list(counts.index),
    y=list(counts.values),
    text=list(counts.index),
    marker=dict(
        color='green',
        ),
)

data = [trace0]
layout = pogo.Layout(
    title='Senators / Reps Bill Sponsorship Counts, 2015-2016',
)

fig = pogo.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="5d515fe3-3cd2-41ff-a3fd-2f1da62df456" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5d515fe3-3cd2-41ff-a3fd-2f1da62df456", [{"text": ["Hartsell (S)", "Glazier (H)", "B.Jackson (S)", "Apodaca (S)", "Tarte (S)", "Horn (H)", "Saine (H)", "Tillman (S)", "Bryan (H)", "Daniel (S)", "Rabon (S)", "Bingham (S)", "Jordan (H)", "Harrison (H)", "Brock (S)", "Hise (S)", "Lewis (H)", "Jeter (H)", "McGrady (H)", "Brown (S)", "Lambeth (H)", "Stam (H)", "D.Davis (S)", "Hager (H)", "Rucho (S)", "Tucker (S)", "Pate (S)", "Whitmire (H)", "Faircloth (H)", "Hanes (H)", "Meredith (S)", "Dobson (H)", "Fisher (H)", "McKissick (S)", "Avila (H)", "Barefoot (S)", "Cook (S)", "Wade (S)", "Stein (S)", "Stevens (H)", "Meyer (H)", "Hurley (H)", "L.Hall (H)", "Barringer (S)", "Dollar (H)", "S.Martin (H)", "Cleveland (H)", "Gunn (S)", "Setzer (H)", "Sanderson (S)", "Foushee (S)", "Elmore (H)", "Tine (H)", "Torbett (H)", "Cotham (H)", "J.Davis (S)", "Lee (S)", "Collins (H)", "McNeill (H)", "J.Bell (H)", "Krawiec (S)", "Jones (H)", "Randleman (S)", "Pendleton (H)", "Riddell (H)", "Daughtry (H)", "Malone (H)", "Woodard (S)", "Lowe (S)", "Blackwell (H)", "Holloway (H)", "Hardister (H)", "Brawley (H)", "G.Martin (H)", "Bishop (H)", "Conrad (H)", "Clark (S)", "Newton (S)", "Ross (H)", "Brockman (H)", "L.Johnson (H)", "Harrington (S)", "B.Brown (H)", "Dixon (H)", "Rabin (S)", "Burr (H)", "Bradford (H)", "Soucek (S)", "Smith (S)", "Robinson (S)", "Millis (H)", "Pierce (H)", "Smith-Ingram (S)", "J.Jackson (S)", "Insko (H)", "Iler (H)", "Boles (H)", "Brody (H)", "R.Turner (H)", "D.Hall (H)", "Davis (H)", "Floyd (H)", "Jackson (H)", "Adcock (H)", "Farmer-Butterfield (H)", "Cunningham (H)", "Howard (H)", "Szoka (H)", "West (H)", "VanDuyn (S)", "Luebke (H)", "Bryant (S)", "Reives (H)", "Carney (H)", "Goodman (H)", "Speciale (H)", "R.Moore (H)", "Hamilton (H)", "Steinburg (H)", "Curtis (S)", "Lucas (H)", "B.Turner (H)", "Presnell (H)", "Warren (H)", "Waddell (H)", "Shepard (H)", "C.Graham (H)", "McInnis (S)", "Pittman (H)", "Alexander (H)", "Salmon (H)", "McElraft (H)", "Ford (S)", "Schaffer (H)", "Blust (H)", "Waddell (S)", "Wells (S)", "Langdon (H)", "Earle (H)", "Arp (H)", "Hunter (H)", "L.Bell (H)", "Ager (H)", "Blue (S)", "Zachary (H)", "Wray (H)", "R.Johnson (H)", "Gill (H)", "Queen (H)", "Alexander (S)", "Terry (H)", "R.Brown (H)", "Michaux (H)", "Baskerville (H)", "Catlin (H)", "Bumgardner (H)", "Fraley (H)", "Ford (H)", "Robinson (H)", "Committee on Rules, Calendar, and Operations of the   House. (H)", "Holley (H)", "Richardson (H)", "Adams (H)", "Yarborough (H)", "J.Moore (H)", "Hastings (H)", "Murphy (H)", "Watford (H)", "Berger (S)", "Willingham (H)", "Brisson (H)", "B.Richardson (H)", "W.Richardson (H)", "T.Moore (H)", "G.Graham (H)", "Chaudhuri (S)", "K.Hall (H)", "Sgro (H)", "Johnson (H)", "Adcock (S)", "Committee on Ethics. (H)", "Ballard (S)"], "type": "bar", "y": [69, 69, 62, 57, 54, 52, 51, 50, 49, 49, 49, 48, 47, 47, 47, 46, 44, 44, 44, 43, 43, 42, 42, 41, 41, 39, 38, 38, 37, 36, 36, 34, 34, 34, 33, 33, 33, 33, 32, 32, 31, 31, 31, 31, 30, 29, 29, 29, 28, 28, 28, 28, 27, 27, 27, 27, 27, 27, 26, 26, 26, 26, 26, 25, 25, 25, 25, 25, 25, 24, 24, 24, 23, 23, 23, 23, 23, 23, 23, 22, 22, 22, 22, 22, 22, 22, 21, 21, 21, 21, 21, 21, 20, 20, 20, 20, 20, 20, 20, 20, 19, 19, 19, 18, 18, 18, 18, 17, 17, 17, 17, 17, 17, 16, 16, 16, 16, 15, 15, 15, 14, 14, 14, 14, 14, 14, 14, 13, 13, 13, 13, 13, 12, 12, 12, 11, 11, 11, 11, 11, 11, 11, 10, 10, 10, 10, 10, 10, 9, 9, 9, 9, 8, 8, 8, 8, 8, 8, 7, 7, 7, 7, 6, 6, 6, 6, 6, 5, 5, 4, 4, 3, 3, 2, 2, 2, 2, 1, 1, 1, 1, 1], "marker": {"color": "green"}, "x": ["Hartsell (S)", "Glazier (H)", "B.Jackson (S)", "Apodaca (S)", "Tarte (S)", "Horn (H)", "Saine (H)", "Tillman (S)", "Bryan (H)", "Daniel (S)", "Rabon (S)", "Bingham (S)", "Jordan (H) ...

# %%
# If has '.', check against FILN; else, check against LastName
lu = {}
for n,h in zip(sponsor_count_data.name, sponsor_count_data.house):
    if h == 'H':
        if n.find('.') > -1:
            ind = numpy.where(house_2016_ele.FILN == n)[0]
        else:
            ind = numpy.where(house_2016_ele.LastName == n)[0]
        if ind.shape[0] == 1:
            ind = ind[0]
        else:
            ind = -1
        lu[n] = ind
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-3b21391d03bb> in <module>()
#       6             ind = numpy.where(house_2016_ele.FILN == n)[0]
#       7         else:
# ----> 8             ind = numpy.where(house_2016_ele.LastName == n)[0]
#       9         if ind.shape[0] == 1:
#      10             ind = ind[0]
#
# /home/immersinn/.virtualenvs/ncga/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'LastName'
