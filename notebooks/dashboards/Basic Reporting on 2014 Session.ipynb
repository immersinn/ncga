# %%
import numpy
import scipy
import pandas

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %matplotlib inline

# %%
import plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly import figure_factory as FF
import plotly.graph_objs as pogo
from plotly.graph_objs import Marker, Line, Data

init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
sys.path.append(os.path.join(os.path.abspath('../..'), 'src'))
sys.path.append(os.path.join(os.path.abspath('../..'), 'data'))

# %%
from importlib import reload

# %%
import utils
import bill_sponsor_analysis_pipeline

# %%
main_repo_dir = utils.get_main_dir()

# %%
reload(bill_sponsor_analysis_pipeline)
# Out:
# <module 'bill_sponsor_analysis_pipeline' from '/home/immersinn/gits/ncga/src/bill_sponsor_analysis_pipeline.py'>

# %%
reprs_info, bill_info, sponsor_info = bill_sponsor_analysis_pipeline.main('2014')

# %%
reprs_info.head()
# Out:
#    District Session Chamber                       Name Party Incombant  \
# 35       36    2014       S  Fletcher L. Hartsell, Jr.     R        NA
# 93       44    2014       H               Rick Glazier     D        NA
# 9        10    2014       S              Brent Jackson     R        NA
# 47       48    2014       S                Tom Apodaca     R        NA
# 40       41    2014       S                 Jeff Tarte     R        NA
#
#              Label  BillCount
# 35  F.Hartsell (R)         69
# 93   R.Glazier (D)         69
# 9    B.Jackson (R)         62
# 47   T.Apodaca (R)         57
# 40     J.Tarte (R)         54

# %%
sponsor_info.head()
# Out:
#    bill_ix chamber     name  sponsor_ix
# 0        0       H    Lewis         102
# 1        1       H    Lewis         102
# 2        2       H  McGrady         166
# 3        2       H    Dixon          53
# 4        3       H   Cotham         149

# %%
bill_info.head()
# Out:
#   Session Chamber  Bill                                            Content  \
# 0  2015E4       H     1  GENERAL ASSEMBLY OF NORTH CAROLINA  FOURTH EXT...
# 1  2015E4       H     2  GENERAL ASSEMBLY OF NORTH CAROLINA  FOURTH EXT...
# 2  2015E4       H     3  GENERAL ASSEMBLY OF NORTH CAROLINA  FOURTH EXT...
# 3  2015E4       H     4  GENERAL ASSEMBLY OF NORTH CAROLINA  FOURTH EXT...
# 4  2015E4       H     5  GENERAL ASSEMBLY OF NORTH CAROLINA  FOURTH EXT...
#
#                                            LongTitle  \
# 0  A HOUSE RESOLUTION adopting the permanent rule...
# 1  A JOINT RESOLUTIOn providing for adjournment s...
# 2  AN ACT to provide further REGULATORY RELIEF TO...
# 3  AN ACT directing the department of transportat...
# 4  AN ACT to clarify the service area for communi...
#
#                                            TableInfo  \
# 0  {'Sponsors': 'Representative Lewis.', 'Referre...
# 1  {'Sponsors': 'Representative Lewis.', 'Referre...
# 2  {'Sponsors': 'Representatives McGrady and Dixo...
# 3  {'Sponsors': 'Representatives Cotham, Bradford...
# 4  {'Sponsors': 'Representative S. Martin.', 'Ref...
#
#                                             Keywords  \
# 0  [ADOPTED, GENERAL ASSEMBLY, RESOLUTIONS, SIMPL...
# 1  [ADJOURNMENT, GENERAL ASSEMBLY, RESOLUTIONS, J...
# 2  [ADMINISTRATION DEPT., ADMINISTRATIVE CODE, AD...
# 3  [BRIDGES, CONTRACTS, COUNTIES, INFRASTRUCTURE,...
# 4  [COUNTIES, EDGECOMBE COUNTY, INFORMATION TECHN...
#
#                       Sponsors
# 0                      [Lewis]
# 1                      [Lewis]
# 2             [McGrady, Dixon]
# 3  [Cotham, Bradford, J.Moore]
# 4                   [S.Martin]

# %% [markdown]
# ## Counting, Basic Analysis

# %%
total_bills = bill_info.shape[0]
sen_bills = sum(bill_info.house == 'S')
hou_bills = sum(bill_info.house == 'H')

# %% [markdown]
# ## Breakdown by Rep

# %%
color_dict = {'R' : 'red', 'D' : 'blue'}

trace0 = pogo.Bar(
    x=list(reprs_info['Label']),
    y=list(reprs_info['BillCount']),
    text=list(reprs_info['Label']),
    marker=dict(
        color=[color_dict[p] for p in reprs_info['Party']],
        ),
)

data = [trace0]
layout = pogo.Layout(
    title='NC GA Bill Sponsorship Counts, 2015-2016',
)

fig = pogo.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="840e8899-ee58-4783-92a9-1f00b5d9ce4f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("840e8899-ee58-4783-92a9-1f00b5d9ce4f", [{"marker": {"color": ["red", "blue", "red", "red", "red", "red", "red", "red", "red", "red", "red", "red", "blue", "red", "red", "red", "red", "red", "red", "red", "red", "red", "blue", "red", "red", "red", "red", "red", "red", "blue", "red", "blue", "red", "blue", "red", "red", "red", "red", "red", "blue", "red", "blue", "blue", "red", "red", "red", "red", "red", "red", "red", "blue", "red", "blue", "red", "red", "blue", "red", "blue", "red", "red", "red", "red", "red", "red", "red", "red", "red", "red", "blue", "blue", "red", "red", "red", "red", "blue", "red", "red", "red", "blue", "red", "red", "red", "blue", "red", "red", "red", "red", "blue", "blue", "red", "red", "red", "blue", "red", "blue", "blue", "red", "red", "blue", "red", "red", "blue", "blue", "blue", "blue", "red", "blue", "red", "blue", "blue", "red", "blue", "blue", "blue", "blue", "red", "blue", "blue", "red", "red", "red", "blue", "red", "blue", "red", "blue", "blue", "blue", "red", "red", "blue", "red", "red", "red", "blue", "blue", "blue", "blue", "red", "red", "blue", "red", "blue", "blue", "blue", "blue", "red", "blue", "blue", "red", "blue", "blue", "red", "red", "red", "red", "red", "blue", "blue", "blue", "red", "red", "red", "red", "red", "red", "red", "blue", "blue", "blue", "blue", "blue", "red", "red", "red", "blue", "blue", "blue", "red", "red", "blue", "red"]}, "type": "bar", "y": [69, 69, 62, 57, 54, 52, 51, 50, 49, 49, 49, 48, 47, 47, 47, 46, 44, 44, 44, 43, 43, 42, 42, 41, 41, 39, 38, 38, 37, 36, 36, 34, 34, 34, 33, 33, 33, 33, 32, 32, 31, 31, 31, 31, 30, 29, 29, 29, 28, 28, 28, 28, 28, 27, 27, 27, 27, 27, 27, 26, 26, 26, 26, 26, 25, 25, 25, 25, 25, 25, 24, 24, 24, 23, 23, 23, 23, 23, 23, 23, 23, 22, 22, 22, 22, 22, 22, 21, 21, 21, 21, 21, 20, 20, 20, 20, 20, 20, 20, 20, 19, 19, 19, 19, 18, 18, 18, 17, 17, 17, 17, 17, 17, 16, 16, 16, 16, 15, 15, 15, 14, 14, 14, 14, 14, 14, 14, 13, 13, 13, 13, 13, 12, 12, 12, 11, 11, 11, 11, 11, 11, 11, 10, 10, 10, 10, 10, 10, 10, 9, 9, 9, 9, 8, 8, 8, 8, 8, 8, 7, 6, 6, 6, 6, 6, 5, 5, 4, 4, 3, 2, 2, 2, 2, 1, 1, 0, 0, 0, 0, 0, 0], "x": ["F.Hartsell (R)", "R.Glazier (D)", "B.Jackson (R)", "T.Apodaca (R)", "J.Tarte (R)", "D.Horn (R)", "J.Saine (R)", "J.Tillman (R)", "W.Daniel (R)", "R.Bryan (R)", "B.Rabon (R)", "S.Bingham (R)", "M.Harrison (D)", "A.Brock (R)", "J.Jordan (R)", "R.Hise (R)", "D.Lewis (R)", "C.McGrady (R)", "C.Jeter (R)", "H.Brown (R)", "D.Lambeth (R)", "P.Stam (R)", "D.Davis (D)", "B.Rucho (R)", "M.Hager (R)", "T.Tucker (R)", "C.Whitmire (R)", "L.Pate (R)", "J.Faircloth (R)", "E.Hanes (D)", "W.Meredith (R)", "F.McKissick (D)", "J.Dobson (R)", "S.Fisher (D)", "M.Avila (R)", "B.Cook (R)", "T.Wade (R)", "C.Barefoot (R)", "S.Stevens (R)", "J.Stein (D)", "T.Barringer (R)", "L.Hall (D)", "G.Meyer (D)", "P.Hurley (R)", "N.Dollar (R)", "G.Cleveland (R)", "R.Gunn (R)", "S.Martin (R)", "N.Sanderson (R)", "M.Setzer (R)", "V.Foushee (D)", "J.Elmore (R)", "G.Robinson (D)", "J.Torbett (R)", "M.Lee (R)", "T.Cotham (D)", "J.Collins (R)", "P.Tine (D)", "J.Davis (R)", "J.Bell (R)", "B.Jones (R)", "S.Randleman (R)", "A.McNeill (R)", "J.Krawiec (R)", "G.Pendleton (R)", "D.Riddell (R)", "C.Malone (R)", "N.Daughtry (R)", "P.Lowe (D)", "M.Woodard (D)", "J.Hardister (R)", "H.Blackwell (R)", "B.Holloway (R)", "D.Bishop (R)", "G.Martin (D)", "S.Ross (R)", "L.Johnson (R)", "E.Newton (R)", "B.Clark (D)", "D.Conrad (R)", "W.Brawley (R)", "J.Dixon (R)", "C.Brockman (D)", "R.Rabin (R)", "K.Harrington (R)", "J.Burr (R)", "B.Brown (R)", "G.Pierce (D)", "J.Smith (D)", "C.Millis (R)", "D.Soucek (R)", "J.Bradford (R)", "J.Jackson (D)", "J.Boles (R)", "D.Hall (D)", "V.Insko (D)", "F.Iler (R)", "M.Brody (R)", "E.Smith ...

# %%
sponsor_summary_url = plot(fig, filename='images/NC GA Bill Sponsorship Counts 2015-201.html', auto_open=False,)
sponsor_summary_url = sponsor_summary_url[7:]

# %% [markdown]
# ### Helper Stuff

# %%
name_suffix_list = ['Jr', 'Sr', 'II', 'III', 'IV']

def get_last_name(full_name):
    name_parts = [p.strip() for p in full_name.split()]
    name_parts = [p for p in name_parts if p]
    
    last = ''
    if name_parts[-1].strip('.') not in name_suffix_list:
        last = name_parts[-1]
    else:
        last = name_parts[-2].strip(',')
    return(last)

def get_first_name(full_name):
    return(full_name.split()[0])

def get_firstinit(full_name):
    return(full_name[0])

def build_repr_ballotpedia_link(full_name):
    url_base = "https://ballotpedia.org/"
    url = url_base + get_first_name(full_name) + "_" + get_last_name(full_name)
    return(url)

def build_district_ballotpedia_link(district_no, chamber):
    url_base = "https://ballotpedia.org/"
    chamber_base = {'H' : 'North_Carolina_House_of_Representatives_',
                    'S' : 'North_Carolina_State_Senate_'}
    url = url_base + chamber_base[chamber] + 'District_' + str(district_no)
    return(url)

def build_ahref_link(text, url):
    return('<a href="' + url + '">' + text + '</a>')

# %%
reprs_info['PersonURL'] = reprs_info.Name.apply(build_repr_ballotpedia_link)
reprs_info['DistrictURL'] = reprs_info.apply(lambda x: build_district_ballotpedia_link(x.District, x.Chamber),
                                             axis=1)
reprs_info['District'] = reprs_info.District.apply(lambda x: 'District ' + str(x))

# %%
def build_chamber_summary_table(all_reps, chamber, sort_by='LN'):
    peeps = reprs_info[reprs_info.Chamber == chamber].copy()
    
    if sort_by=='LN':
        peeps['LN'] = peeps.Name.apply(get_last_name)
    
    peeps.sort_values(by=sort_by, inplace=True)
    
    data_matrix = [['Name', 'District', 'Party', 'Bills Sponsored']]

    for n,d,p,b in zip(peeps.apply(lambda x: build_ahref_namelink(x.Name, x.PersonURL), axis=1),
                       peeps.apply(lambda x: build_ahref_namelink(x.District, x.DistrictURL), axis=1),
                       peeps.Party,
                       peeps.BillCount):
        data_matrix.append([n,d,p,b])
        
    table = FF.create_table(data_matrix)
    table_url = plot(table, filename='images/' + chamber + '_rep_table.html', auto_open=False,)
    table_url = table_url[7:]
    
    return(table_url)

# %% [markdown]
# ### House Table

# %%
house_table_url = build_chamber_summary_table(reprs_info, 'H')

# %% [markdown]
# ### SenateTable

# %%
senate_table_url = build_chamber_summary_table(reprs_info, 'S')

# %% [markdown]
# ## Section 3: Bill Summary Data

# %%
from collections import defaultdict

# %%
bill_info.keywords[0]
# Out:
# ['ADOPTED',
#  'GENERAL ASSEMBLY',
#  'RESOLUTIONS',
#  'SIMPLE',
#  'RULES',
#  'HOUSE & SENATE']

# %%
def build_chamber_keywords_table(bill_info, chamber, cutoff=10):
    kw_table = FF.create_table(bill_proc_utils.build_chamber_keywords_df(bill_info, chamber))
    table_url = plot(kw_table, filename='images/' + chamber + '_keyword_table.html', auto_open=False,)
    table_url = table_url[7:]
    
    return(table_url)

# %%
house_kwtable_url = build_chamber_keywords_table(bill_info, 'H')
senate_kwtable_url = build_chamber_keywords_table(bill_info, 'S')

# %% [markdown]
# # Generate HTML as a String and Write to File

# %%
html_string = '''
<html>
    <head>
        <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.1/css/bootstrap.min.css">
        <style>body{ margin:0 100; background:whitesmoke; }</style>
    </head>
    <body>
        <h1>NCGA: Summary Info for Bills Filed During 2015 - 2016 Session</h1>

        <!-- *** Section 1 *** --->
        <h2>Section 1: General Summary Info</h2>
            <h4>Total Bills Filed: ''' + str(total_bills) + '''</h4>
            <h4>Senate Bills Filed: ''' + str(sen_bills) + '''</h4>
            <h4>House Bills Filed: ''' + str(hou_bills) + '''</h4>

        
        <!-- *** Section 2 *** --->
        <h2>Section 2: Breakdown by Representative</h2>

            <iframe width="1500" height="800" frameborder="0" seamless="seamless" scrolling="no"\
    src="''' + sponsor_summary_url + '''"></iframe>
    
    
        <table width="100%">
                <tr>
                    <td width="48%"><h3>House of Representatives Summary</h3></td>
                    <td width="48%"><h3>Senate Summary</h3></td>
                </tr>
            </table>
        
        <iframe style="padding:40px" width="48%" height="480" frameborder="0" seamless="seamless" scrolling="yes" align="left"\
    src="''' + house_table_url + '''"></iframe>
    
        <iframe style="padding:40px" width="48%" height="480" frameborder="0" seamless="seamless" scrolling="yes" align="right"\
    src="''' + senate_table_url + '''"></iframe>
    
    
        <!-- *** Section 3 *** --->
        <h2>Section 3: Bill Topics Overview</h2>
        
            <p>Table with keyword info, other topic info goes here</p>
            
            <table width="100%">
                <tr>
                    <td width="48%"><h3>House of Representatives</h3></td>
                    <td width="48%"><h3>Senate</h3></td>
                </tr>
            </table>
        
        <iframe style="padding:40px" width="48%" height="480" frameborder="0" seamless="seamless" scrolling="yes" align="left"\
    src="''' + house_kwtable_url + '''"></iframe>
    
        <iframe style="padding:40px" width="48%" height="480" frameborder="0" seamless="seamless" scrolling="yes" align="right"\
    src="''' + senate_kwtable_url + '''"></iframe>

    
    </body>
</html>'''

# %%
with open(os.path.join(main_repo_dir,'reports/dashboards/NCGABillsSummary.html'),'w') as f:
    f.write(html_string)
